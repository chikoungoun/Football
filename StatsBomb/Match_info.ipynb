# %%
import json
import pprint

# %%
with open('4.json',encoding="utf-8") as data:
    events = json.load(data)

# %%
events
# Out:
# [{'match_id': 7298,
#   'match_date': '2018-02-24',
#   'kick_off': '20:45:00.000',
#   'competition': {'competition_id': 37,
#    'country_name': 'England',
#    'competition_name': "FA Women's Super League"},
#   'season': {'season_id': 4, 'season_name': '2018/2019'},
#   'home_team': {'home_team_id': 746,
#    'home_team_name': 'Manchester City WFC',
#    'home_team_gender': 'female',
#    'home_team_group': None,
#    'country': {'id': 68, 'name': 'England'},
#    'managers': [{'id': 30,
#      'name': 'Nick Cushing',
#      'nickname': None,
#      'dob': '1984-11-09',
#      'country': {'id': 68, 'name': 'England'}}]},
#   'away_team': {'away_team_id': 971,
#    'away_team_name': 'Chelsea FCW',
#    'away_team_gender': 'female',
#    'away_team_group': None,
#    'country': {'id': 68, 'name': 'England'},
#    'managers': [{'id': 152,
#      'name': 'Emma Hayes',
#      'nickname': None,
#      'dob': '1976-10-18',
#      'country': {'id': 68, 'name': 'England'}}]},
# ...

# %%
for i in events:
    pprint.pprint(i)
# Out:
# {'away_score': 2,
#  'away_team': {'away_team_gender': 'female',
#                'away_team_group': None,
#                'away_team_id': 971,
#                'away_team_name': 'Chelsea FCW',
#                'country': {'id': 68, 'name': 'England'},
#                'managers': [{'country': {'id': 68, 'name': 'England'},
#                              'dob': '1976-10-18',
#                              'id': 152,
#                              'name': 'Emma Hayes',
#                              'nickname': None}]},
#  'competition': {'competition_id': 37,
#                  'competition_name': "FA Women's Super League",
#                  'country_name': 'England'},
#  'competition_stage': {'id': 1, 'name': 'Regular Season'},
#  'home_score': 2,
#  'home_team': {'country': {'id': 68, 'name': 'England'},
#                'home_team_gender': 'female',
#                'home_team_group': None,
#                'home_team_id': 746,
# ...

# %% [markdown]
# ### Find match match id

# %%
for x,i in enumerate(events):
    print(i['match_id'])
    
    if x > 5:
        break
# Out:
# 7298
# 19778
# 19771
# 19736
# 19745
# 19772
# 19730

# %% [markdown]
# ### Find managers name

# %%
for x,i in enumerate(events):
    print(i['home_team']['managers'][0]['name'])
    
    if x > 5:
        break
# Out:
# Nick Cushing
# Nick Cushing
# Marc Skinner
# Emma Hayes
# Hope Patricia Powell
# Emma Hayes
# Emma Hayes

# %% [markdown]
# ### Find match date

# %%
for x,i in enumerate(events):
    print(i['match_date'])
    
    if x > 5:
        break
# Out:
# 2018-02-24
# 2018-12-09
# 2018-12-02
# 2018-10-14
# 2018-10-28
# 2018-12-02
# 2018-09-30

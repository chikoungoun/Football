# %% [markdown]
# # Compute a convex hull

# %%
import numpy as np

# %%
from scipy.spatial import ConvexHull, convex_hull_plot_2d
rng = np.random.default_rng()
points = rng.random((30,2))
hull = ConvexHull(points)

# %%
points[:5]
# Out:
# array([[0.6296639 , 0.98516796],
#        [0.9103429 , 0.88666051],
#        [0.543627  , 0.24473839],
#        [0.45199235, 0.86485851],
#        [0.04331589, 0.76477688]])

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# points[:,0] = represents all the x points
# points[:,1] = represents all the y points

plt.plot(points[:,0],points[:,1],'o')

for simplex in hull.simplices:
    plt.plot(points[simplex,0],points[simplex,1],'k-')

# %% [markdown]
# ## Plotting the points with the scatter function

# %%
fig,ax = plt.subplots(figsize=(28,16))

plt.scatter(points[:,0],points[:,1])

for simplex in hull.simplices:
    plt.plot(points[simplex,0],points[simplex,1],'k-')
